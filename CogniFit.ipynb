# %% [markdown]
# <a href="https://colab.research.google.com/github/Armin-Abdollahi/WhiteTree-International-Academy/blob/main/CogniFit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# Load the Excel file
file_path = '/content/C.xlsx'
df = pd.read_excel(file_path)

# Create separate DataFrames for each task
inhibition_df = df[df['task_name'] == 'Inhibition of Return Test']
selective_attention_df = df[df['task_name'] == 'Selective Attention Test']
visual_memory_df = df[df['task_name'] == 'Visual Memory Test']
digit_span_df = df[df['task_name'] == 'Digit Span Test']
maze_df = df[df['task_name'] == 'Maze Test']
visual_working_memory_df = df[df['task_name'] == 'Visual Working Memory Span Test']
eye_hand_coordination_mud_df = df[df['task_name'] == 'Eye-Hand Coordination Test (MUD)']
eye_hand_coordination_ftud_df = df[df['task_name'] == 'Eye-Hand Coordination Test (FTUD)']
psychomotor_vigilance_df = df[df['task_name'] == 'Psychomotor Vigilance Test']

# ------------------------------------ Analysis for Inhibition of Return Test ------------------------------------
print("Performing analysis for Inhibition of Return Test")
# Insert your analysis code here
# Example: calculate the mean of a column
# mean_value_inhibition = inhibition_df['your_column_name'].mean()
# print(f'Mean value for Inhibition of Return Test: {mean_value_inhibition}')




# ------------------------------------- Analysis for Selective Attention Test ------------------------------------
print("Performing analysis for Selective Attention Test")
# Insert your analysis code here
# Example: calculate the mean of a column
# mean_value_selective_attention = selective_attention_df['your_column_name'].mean()
# print(f'Mean value for Selective Attention Test: {mean_value_selective_attention}')




# ---------------------------------------- Analysis for Visual Memory Test ---------------------------------------
print("Performing analysis for Visual Memory Test")
# Insert your analysis code here
# Example: calculate the mean of a column
# mean_value_visual_memory = visual_memory_df['your_column_name'].mean()
# print(f'Mean value for Visual Memory Test: {mean_value_visual_memory}')




# ----------------------------------------- Analysis for Digit Span Test -----------------------------------------
print("Performing analysis for Digit Span Test")
# Insert your analysis code here
# Example: calculate the mean of a column
# mean_value_digit_span = digit_span_df['your_column_name'].mean()
# print(f'Mean value for Digit Span Test: {mean_value_digit_span}')




# -------------------------------------------- Analysis for Maze Test --------------------------------------------
print("Performing analysis for Maze Test")
# Insert your analysis code here
# Example: calculate the mean of a column
# mean_value_maze = maze_df['your_column_name'].mean()
# print(f'Mean value for Maze Test: {mean_value_maze}')




# --------------------------------- Analysis for Visual Working Memory Span Test ---------------------------------
print("Performing analysis for Visual Working Memory Span Test")
# Insert your analysis code here
# Example: calculate the mean of a column
# mean_value_visual_working_memory = visual_working_memory_df['your_column_name'].mean()
# print(f'Mean value for Visual Working Memory Span Test: {mean_value_visual_working_memory}')




# --------------------------------- Analysis for Eye-Hand Coordination Test (MUD) --------------------------------
print("Performing analysis for Eye-Hand Coordination Test (MUD)")
# Insert your analysis code here
# Example: calculate the mean of a column
# mean_value_eye_hand_coordination_mud = eye_hand_coordination_mud_df['your_column_name'].mean()
# print(f'Mean value for Eye-Hand Coordination Test (MUD): {mean_value_eye_hand_coordination_mud}')




# -------------------------------- Analysis for Eye-Hand Coordination Test (FTUD) --------------------------------
print("Performing analysis for Eye-Hand Coordination Test (FTUD)")
# Insert your analysis code here
# Example: calculate the mean of a column
# mean_value_eye_hand_coordination_ftud = eye_hand_coordination_ftud_df['your_column_name'].mean()
# print(f'Mean value for Eye-Hand Coordination Test (FTUD): {mean_value_eye_hand_coordination_ftud}')




# ----------------------------------- Analysis for Psychomotor Vigilance Test ------------------------------------
print("Performing analysis for Psychomotor Vigilance Test")
# Insert your analysis code here
# Example: calculate the mean of a column
# mean_value_psychomotor_vigilance = psychomotor_vigilance_df['your_column_name'].mean()
# print(f'Mean value for Psychomotor Vigilance Test: {mean_value_psychomotor_vigilance}')




print("DataFrames for each task have been created and ready for analysis.")
# Out:
# Performing analysis for Inhibition of Return Test
# Performing analysis for Selective Attention Test
# Performing analysis for Visual Memory Test
# Performing analysis for Digit Span Test
# Performing analysis for Maze Test
# Performing analysis for Visual Working Memory Span Test
# Performing analysis for Eye-Hand Coordination Test (MUD)
# Performing analysis for Eye-Hand Coordination Test (FTUD)
# Performing analysis for Psychomotor Vigilance Test
# DataFrames for each task have been created and ready for analysis.

# %%
# محاسبه سن دقیق بر حسب تاریخ تولد و تاریخ انجام تست
from datetime import datetime

# Function to calculate age
def calculate_age(birth_date, test_date):
    birth_date = datetime.strptime(birth_date, "%Y-%m-%d")
    test_date = datetime.strptime(test_date, "%Y-%m-%d")
    age = test_date.year - birth_date.year - ((test_date.month, test_date.day) < (birth_date.month, birth_date.day))
    return age

# Example usage
birth_date = '1990-05-15'
test_date = '2025-02-02'
age = calculate_age(birth_date, test_date)
print(f"Age: {age} years")

# %%
# فیلتر کردن بر اساس پارامترهایی مثل یوزر آیدی، تاریخ و نوع اسسمنت

import pandas as pd

# Load the Excel file
df = pd.read_excel('your_file.xlsx')

# Function to filter the dataframe
def filter_data(user_id=None, assessment_type=None, task_name=None):
    filtered_df = df
    if user_id is not None:
        filtered_df = filtered_df[filtered_df['user_id'] == user_id]
    if assessment_type is not None:
        filtered_df = filtered_df[filtered_df['assessment_type'] == assessment_type]
    if task_name is not None:
        filtered_df = filtered_df[filtered_df['task_name'] == task_name]
    return filtered_df

# Example usage
filtered_df = filter_data(user_id=1, assessment_type='2025-02-02', task_name='Task A')

# Save the filtered dataframe to a new Excel file
filtered_df.to_excel('filtered_file.xlsx', index=False)

# %%
# دستورهای شرطی برای توضیحات جدول
import pandas as pd

# Load the Excel file
df = pd.read_excel('your_file.xlsx')

# Function to get description based on Score
def get_description(score):
    if 0 <= score <= 20:
        return (
            "Your performance on the Psychomotor Vigilance Test (PVT) is significantly below average. This indicates a high level of inattention and slow reaction times, which could affect your daily activities, learning achievements, and overall cognitive functioning. It's important to consider strategies or interventions to improve your attention and reaction times.",
            "Your eye-hand coordination is significantly below average. This level of performance may indicate severe difficulties in tasks requiring precise movements and coordination. Such challenges can affect daily activities, learning achievements, and academic performance. You may experience problems with writing, using tools, or playing sports. It's important to consider activities or therapies to improve coordination skills and cognitive abilities.",
            "Your visual working memory span is significantly below average. This level of performance may indicate severe difficulties in tasks requiring short-term memory and visual-spatial processing. Such challenges can affect daily activities, learning achievements, and overall cognitive functioning. Consider strategies or therapies to improve your visual memory and cognitive skills.",
            "Your performance on the Maze Test is significantly below average. This level of performance may indicate severe difficulties in planning and visual-spatial problem-solving. Such challenges can affect daily activities and overall cognitive functioning. Consider strategies or therapies to improve your planning and spatial perception skills.",
            "your phonological memory span is significantly below average. This indicates severe difficulties in retaining and recalling sequences of numbers. Such challenges can affect daily activities, learning achievements, and overall cognitive functioning. Consider strategies or therapies to improve your short-term memory and processing speed.",
            "Your visual memory and recognition abilities are significantly below average. This indicates severe difficulties in remembering and recognizing visual patterns. Such challenges can affect daily activities, learning achievements, and overall cognitive functioning. Consider strategies or therapies to improve your visual memory and processing speed.",
            "Your hand-eye coordination and updating abilities are significantly below average. This indicates severe difficulties in tracking moving objects and making necessary adjustments. Such challenges can affect daily activities, learning achievements, and overall cognitive functioning. Consider strategies or therapies to improve your coordination, updating skills, and processing speed."
        )
    # Add more conditions here as per the other rows in your Excel file
    elif 21 <= score <= 40:
        return (
            "Your performance on the PVT is below average. This suggests that you may struggle with maintaining attention and responding quickly to stimuli. These challenges can impact academic performance, especially in tasks requiring sustained attention. Focused practice and exercises can help enhance your attention and reaction speed.",
            "Your eye-hand coordination is below average. This score suggests that you may face difficulties in tasks that require fine motor skills and precise timing. These challenges can impact academic achievements, particularly in subjects that require writing and manual tasks, as well as certain sports and extracurricular activities. Focused practice and exercises can help enhance your coordination and cognitive skills.",
            "Your visual working memory span is below average. This score suggests that you may struggle with tasks that require remembering sequences of visual information. These challenges can impact academic performance and activities requiring strong visual-spatial skills. Focused practice and exercises can help enhance your memory span and cognitive abilities.",
            "Your performance on the Maze Test is below average. This score suggests that you may struggle with tasks that require planning and visual-spatial problem-solving. These challenges can impact various activities that require strong cognitive skills. Focused practice and exercises can help enhance your planning and spatial perception abilities.",
            "Your phonological memory span is below average. This score suggests that you may struggle with tasks requiring the retention and recall of number sequences. These challenges can impact academic performance and various activities that require strong short-term memory. Focused practice and exercises can help enhance your phonological memory and processing speed.",
            "Your visual memory and recognition abilities are below average. This score suggests that you may struggle with tasks requiring the retention and recognition of visual patterns. These challenges can impact academic performance and various activities that require strong visual memory. Focused practice and exercises can help enhance your visual recognition abilities and processing speed.",
            "Your hand-eye coordination and updating abilities are below average. This score suggests that you may struggle with tasks requiring precise tracking of moving objects and making timely adjustments. These challenges can impact academic performance and various activities that require strong coordination and cognitive flexibility. Focused practice and exercises can help enhance your coordination, updating skills, and processing speed."
        )
    elif 41 <= score <= 60:
        return (
            "Your performance on the PVT is average. This score indicates that your attention and reaction times are within a typical range for daily activities and academic tasks. While there is room for improvement, you are able to perform most tasks without significant issues. Regular cognitive exercises can help maintain and improve your attention and reaction times.",
            "Your eye-hand coordination is average. This score indicates that you have a functional level of coordination suitable for most daily activities and academic tasks. While there is room for improvement, you can perform typical tasks without significant issues. Engaging in regular physical activities and cognitive exercises can help maintain and further develop your coordination skills.",
            "Your visual working memory span is average. This score indicates that your visual memory and cognitive skills are within a typical range for daily activities and academic tasks. While there is room for improvement, you can perform most tasks without significant issues. Regular cognitive exercises can help maintain and improve your visual working memory.",
            "Your performance on the Maze Test is average. This score indicates that your planning and visual-spatial problem-solving skills are within a typical range for daily activities. While there is room for improvement, you can perform most tasks without significant issues. Regular cognitive exercises can help maintain and improve your planning and spatial perception skills.",
            "Your phonological memory span is average. This score indicates that your memory and processing speed are within a typical range for daily activities and academic tasks. While there is room for improvement, you can perform most tasks without significant issues. Regular cognitive exercises can help maintain and improve your phonological memory span.",
            "Your visual memory and recognition abilities are average. This score indicates that your memory and processing speed are within a typical range for daily activities and academic tasks. While there is room for improvement, you can perform most tasks without significant issues. Regular cognitive exercises can help maintain and improve your visual memory span.",
            "Your hand-eye coordination and updating abilities are average. This score indicates that your coordination, updating skills, and processing speed are within a typical range for daily activities and academic tasks. While there is room for improvement, you can perform most tasks without significant issues. Regular cognitive exercises can help maintain and improve your coordination and cognitive flexibility."
        )
    elif 61 <= score <= 80:
        return (
            "Your visual working memory span is above average. This score reflects good visual memory and cognitive skills. You are likely to excel in activities requiring strong visual-spatial skills and memory, such as certain academic tasks and games. Continued practice and challenging yourself with more complex tasks can further enhance your cognitive abilities.",
            "Your performance on the Maze Test is above average. This score reflects good planning and visual-spatial problem-solving skills. You are likely to excel in activities that require strong cognitive skills. Continued practice and challenging yourself with more complex tasks can further enhance your cognitive abilities.",
            "Your visual working memory span is above average. This score reflects good visual memory and cognitive skills. You are likely to excel in activities requiring strong visual-spatial skills and memory, such as certain academic tasks and games. Continued practice and challenging yourself with more complex tasks can further enhance your cognitive abilities.",
            "Your performance on the Maze Test is above average. This score reflects good planning and visual-spatial problem-solving skills. You are likely to excel in activities that require strong cognitive skills. Continued practice and challenging yourself with more complex tasks can further enhance your cognitive abilities.",
            "Your phonological memory span is above average. This score reflects good retention and recall of number sequences. You are likely to excel in activities requiring strong short-term memory and processing speed. Continued practice and challenging yourself with more complex tasks can further enhance your cognitive abilities.",
            "Your visual memory and recognition abilities are above average. This score reflects good retention and recognition of visual patterns. You are likely to excel in activities requiring strong visual memory and processing speed. Continued practice and challenging yourself with more complex tasks can further enhance your cognitive abilities.",
            "Your hand-eye coordination and updating abilities are above average. This score reflects good coordination, updating skills, and processing speed. You are likely to excel in activities requiring strong hand-eye coordination and cognitive flexibility. Continued practice and challenging yourself with more complex tasks can further enhance your cognitive abilities."
        )
    elif 81 <= score <= 100:
        return (
            "Your performance on the PVT is excellent. This high level of performance indicates superior attention and rapid reaction times. You likely excel in activities requiring quick responses and sustained attention. Your strong cognitive abilities contribute positively to overall learning achievement and academic success. Continue to challenge yourself with complex and diverse activities to maintain and further develop your exceptional skills.",
            "Your eye-hand coordination is excellent. This high level of performance indicates superior ability in tasks requiring precise and quick movements. You likely excel in activities requiring fine motor skills and coordination, such as playing musical instruments, sports, and detailed academic tasks. Your strong coordination contributes positively to overall cognitive function, learning achievement, and academic success. Continue to challenge yourself with complex and diverse activities to maintain and further develop your exceptional skills.",
            "Your visual working memory span is excellent. This high level of performance indicates superior visual memory and cognitive skills. You likely excel in activities requiring exceptional memory and visual-spatial processing, such as advanced academic tasks and certain sports. Your strong cognitive abilities contribute positively to overall learning achievement and academic success. Continue to challenge yourself with complex and diverse activities to maintain and further develop your exceptional skills.",
            "Your performance on the Maze Test is excellent. This high level of performance indicates superior planning and visual-spatial problem-solving skills. You likely excel in activities requiring exceptional cognitive abilities. Your strong planning and spatial perception skills contribute positively to overall learning achievement and cognitive success. Continue to challenge yourself with complex and diverse activities to maintain and further develop your exceptional skills.",
            "Your phonological memory span is excellent. This high level of performance indicates superior short-term memory and processing speed. You likely excel in activities requiring exceptional retention and recall abilities. Your strong phonological memory contributes positively to overall learning achievement and cognitive success. Continue to challenge yourself with complex and diverse activities to maintain and further develop your exceptional skills.",
            "Your visual memory and recognition abilities are excellent. This high level of performance indicates superior visual memory and processing speed. You likely excel in activities requiring exceptional retention and recognition abilities. Your strong visual memory contributes positively to overall learning achievement and cognitive success. Continue to challenge yourself with complex and diverse activities to maintain and further develop your exceptional skills.",
            "Your hand-eye coordination and updating abilities are excellent. This high level of performance indicates superior coordination, updating skills, and processing speed. You likely excel in activities requiring exceptional hand-eye coordination and cognitive flexibility. Your strong coordination and updating skills contribute positively to overall learning achievement and cognitive success. Continue to challenge yourself with complex and diverse activities to maintain and further develop your exceptional skills."
        )
    else:
        return ("Unknown Score Range", "Unknown Score Range", "Unknown Score Range", "Unknown Score Range", "Unknown Score Range", "Unknown Score Range", "Unknown Score Range")

# Apply the function to your dataframe
df['Description_PVT'], df['Description_EHCT'], df['Description_VWMS'], df['Description_Maze'], df['Description_DST'], df['Description_VMT'], df['Description_EHCT(MUD)'] = zip(*df['Score'].apply(get_description))

# Save the updated dataframe to a new Excel file
df.to_excel('updated_file.xlsx', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib.backends.backend_pdf import PdfPages
from PyPDF2 import PdfReader, PdfWriter
from google.colab import files
from matplotlib.font_manager import FontProperties

def plot_maker(df, output_pdf='report.pdf', name="Armin Abdollahi", age=25, date="2025-01-31"):
    front_cover_path = '/content/Front_Cover.pdf'
    back_cover_path = '/content/Back_Cover.pdf'

    # Create a PDF object
    pdf = PdfPages(output_pdf)

    # Create a figure with subplots of size A4
    fig = plt.figure(figsize=(8.27, 11.69))  # A4 size in inches

    # ----------------------------------------------- Page 2 -----------------------------------------------
    # Add logo and title to the top-left corner
    logo1 = Image.open('/content/Logo1.png')
    logo1 = logo1.resize((140, 27))  # Resize the logo to a smaller size
    fig.figimage(logo1, 50, fig.bbox.ymax - 50 - logo1.size[1])  # Position the logo at the top-left corner

    # Add personal information to the center-top of the page
    fig.text(0.5, 0.95, "Name:               Age:    Date of Evaluation:", fontsize=10, ha='center')
    fig.text(0.5, 0.93, f"{name}    {age}    {date}", fontsize=10, ha='center')

    # Add the title "CogniFit Profile" close to the figures
    fig.text(0.5, 0.85, "Cognitive Profile", fontsize=12, ha='center', weight='bold')

    # Create a table
    ax1 = fig.add_subplot(2, 2, 1)
    ax1.axis('tight')
    ax1.axis('off')

    # Sample data for the table
    table_data = [['Visual Memory', 'Value 1'], ['Working Memory', 'Value 2'], ['Short-term Memory', 'Value 3'],
                  ['Focus Attention', 'Value 4'], ['Updating', 'Value 5'], ['Hand-Eye Coordination', 'Value 6'],
                  ['Spatial Perception', 'Value 7'], ['Reaction Time', 'Value 8'], ['Processing Speed', 'Value 9'],
                  ['Planning and Reasoning', 'Value 10']]

    # Set column widths: first column wider than the second
    col_widths = [0.69, 0.31]  # 70% for the first column, 30% for the second

    table = ax1.table(cellText=table_data,
                      colLabels=["Cognitive Ability", "Final Score"],
                      cellLoc='center',
                      loc='center',
                      colWidths=col_widths)

    # Modify the font properties of column labels
    for (row, col), cell in table.get_celld().items():
        if row == 0:
            cell.set_text_props(weight='bold', fontsize=12)

    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1, 1.5)

    # Figure 2: Heptagon Plot with 10 parameters
    ax2 = fig.add_subplot(2, 2, 2, polar=True)

    # Use the first 10 elements from table_data for the heptagon
    labels = [row[0] for row in table_data]
    values = np.random.rand(len(labels))  # Generate random data for demonstration

    # Add the first value to the end of the lists to close the heptagon
    values = np.append(values, values[0])
    angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
    angles += angles[:1]  # Add the first angle to the end to close the heptagon

    ax2.fill(angles, values, color='blue', alpha=0.25)
    ax2.plot(angles, values, color='blue', linewidth=1)
    ax2.set_yticklabels([])
    ax2.set_xticks(angles[:-1])
    ax2.set_xticklabels(labels, fontsize=8)

    # Figure 3: Vertical bar chart (Page 2)
    ax3 = fig.add_subplot(2, 1, 2)
    y_pos = np.arange(len(labels))
    values_percent = values[:-1] * 100  # Convert to percentage
    ax3.bar(y_pos, values_percent, align='center')
    ax3.set_xticks(y_pos)
    ax3.set_xticklabels(['\n'.join(label.split()) for label in labels], fontsize=5, rotation=0, ha='center')
    for i, v in enumerate(values_percent):
        ax3.text(i, v + 1, f"{v:.1f}", color='blue', ha='center', fontsize=8)
    ax3.set_ylim(0, 100)  # Set y-axis limit from 0 to 100
    ax3.set_yticks(range(0, 101, 20))  # Set y-axis ticks from 0 to 100 with step of 20
    ax3.set_yticklabels([str(i) for i in range(0, 101, 20)])  # Remove % symbol from y-axis labels
    ax3.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines

    # Add the second logo to the bottom-right corner
    logo2 = Image.open('/content/Logo2.png')
    logo2 = logo2.resize((70, 70))  # Resize the logo to a smaller size
    fig.figimage(logo2, fig.bbox.xmax - 50 - logo2.size[0], fig.bbox.ymin + 50)  # Position the logo at the bottom-right corner

    # Save the first page
    pdf.savefig(fig)
    plt.close(fig)

    # ----------------------------------------------- Page 3 -----------------------------------------------
    fig = plt.figure(figsize=(8.27, 11.69))  # A4 size in inches

    # Add logo and title to the top-left corner
    fig.figimage(logo1, 50, fig.bbox.ymax - 50 - logo1.size[1])  # Position the logo at the top-left corner

    # Add personal information to the center-top of the page
    fig.text(0.5, 0.95, "Name:               Age:    Date of Evaluation:", fontsize=10, ha='center')
    fig.text(0.5, 0.93, f"{name}    {age}    {date}", fontsize=10, ha='center')

    # Add the title "Assessment Results" close to the figures
    fig.text(0.5, 0.85, "Assessment Results", fontsize=12, ha='center', weight='bold')

    # Add a 3-column 7-row table with size matching the bar chart
    ax4 = fig.add_subplot(2, 1, 1)
    ax4.axis('tight')
    ax4.axis('off')

    # Sample data for the table
    table_data_page2 = [['Assessment Name', 'Score', 'Description'],
                        ['Psychomotor Vigilance Test', 'Value 1.2', 'Value 1.3'],
                        ['Eye-Hand Coordination Test', 'Value 2.2', 'Value 2.3'],
                        ['Eye-Hand Coordination MUD', 'Value 3.2', 'Value 3.3'],
                        ['Maze Test', 'Value 4.2', 'Value 4.3'],
                        ['Digit Span Test', 'Value 5.2', 'Value 5.3'],
                        ['Visual Memory Test', 'Value 6.2', 'Value 6.3']]

    # Set column widths: 22% for first column, 11% for second, and the rest (67%) for the third
    col_widths = [0.22, 0.11, 0.67]

    table_page2 = ax4.table(cellText=table_data_page2,
                            cellLoc='center',
                            loc='center',
                            colWidths=col_widths)

    # Modify the font properties of column labels
    for (row, col), cell in table_page2.get_celld().items():
        if row == 0:
            cell.set_text_props(weight='bold', fontsize=12)

    table_page2.auto_set_font_size(False)
    table_page2.set_fontsize(6)
    table_page2.scale(1, 1.5)  # Scale to match bar chart size

    # Figure 4: Vertical bar chart (Page 3)
    ax5 = fig.add_subplot(2, 1, 2)
    labels_page2 = [row[0] for row in table_data_page2[1:]]  # Exclude header row
    values_page2 = np.random.rand(len(labels_page2)) * 100  # Generate random data as percentage
    y_pos_page2 = np.arange(len(labels_page2))
    ax5.bar(y_pos_page2, values_page2, align='center')
    ax5.set_xticks(y_pos_page2)
    ax5.set_xticklabels(['\n'.join(label.split()) for label in labels_page2], fontsize=5, rotation=0, ha='center')
    for i, v in enumerate(values_page2):
        ax5.text(i, v + 1, f"{v:.1f}", color='blue', ha='center', fontsize=8)
    ax5.set_ylim(0, 100)  # Set y-axis limit from 0 to 100
    ax5.set_yticks(range(0, 101, 20))  # Set y-axis ticks from 0 to 100 with step of 20
    ax5.set_yticklabels([str(i) for i in range(0, 101, 20)])  # Remove % symbol from y-axis labels
    ax5.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines

    # Add the second logo to the bottom-right corner
    fig.figimage(logo2, fig.bbox.xmax - 50 - logo2.size[0], fig.bbox.ymin + 50)  # Position the logo at the bottom-right corner

    # Save the second page
    pdf.savefig(fig)
    plt.close(fig)

    # Close the PDF file
    pdf.close()

    # Merge front cover, report, and back cover
    front_pdf = PdfReader(front_cover_path)
    report_pdf = PdfReader(output_pdf)
    back_pdf = PdfReader(back_cover_path)

    output = PdfWriter()

    # Add front cover
    output.add_page(front_pdf.pages[0])

    # Add report pages
    for page in report_pdf.pages:
        output.add_page(page)

    # Add back cover
    output.add_page(back_pdf.pages[0])

    # Save the merged PDF
    with open(output_pdf, 'wb') as f:
        output.write(f)

    # Download the merged PDF
    files.download(output_pdf)

# Example usage with a sample dataframe
data = {
    'Visual Memory': np.random.rand(100),
    'Working Memory': np.random.rand(100),
    'Short-term Memory': np.random.rand(100),
    'Focus Attention': np.random.rand(100),
    'Updating': np.random.rand(100),
    'Hand-Eye Coordination': np.random.rand(100),
    'Spatial Perception': np.random.rand(100),
    'Reaction Time': np.random.rand(100),
    'Processing Speed': np.random.rand(100),
    'Planning and Reasoning': np.random.rand(100),
    'Psychomotor Vigilance Test': np.random.rand(100),
    'Eye-Hand Coordination Test': np.random.rand(100),
    'Eye-Hand Coordination MUD': np.random.rand(100),
    'Maze Test': np.random.rand(100),
    'Digit Span Test': np.random.rand(100),
    'Visual Memory Test': np.random.rand(100),
    'Visual Working Memory Span': np.random.rand(100)
}
df = pd.DataFrame(data)
plot_maker(df)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib.backends.backend_pdf import PdfPages
from PyPDF2 import PdfReader, PdfWriter
from google.colab import files
from matplotlib.font_manager import FontProperties

def plot_maker(df, output_pdf='report.pdf', name="Armin Abdollahi", age=25, date="2025-01-31"):
    front_cover_path = '/content/Front_Cover.pdf'
    back_cover_path = '/content/Back_Cover.pdf'

    # Create a PDF object
    pdf = PdfPages(output_pdf)

    # Create a figure with subplots of size A4
    fig = plt.figure(figsize=(8.27, 11.69))  # A4 size in inches

    # ----------------------------------------------- Page 2 -----------------------------------------------
    # Add logo and title to the top-left corner
    logo1 = Image.open('/content/Logo1.png')
    logo1 = logo1.resize((140, 27))  # Resize the logo to a smaller size
    fig.figimage(logo1, 50, fig.bbox.ymax - 50 - logo1.size[1])  # Position the logo at the top-left corner

    # Add personal information to the center-top of the page
    fig.text(0.5, 0.95, "Name:               Age:    Date of Evaluation:", fontsize=10, ha='center')
    fig.text(0.5, 0.93, f"{name}    {age}    {date}", fontsize=10, ha='center')

    # Add the title "CogniFit Profile" close to the figures
    fig.text(0.5, 0.85, "Cognitive Profile", fontsize=12, ha='center', weight='bold')

    # Create a table
    ax1 = fig.add_subplot(2, 2, 1)
    ax1.axis('tight')
    ax1.axis('off')

    # Extract mean values from the DataFrame
    ability_names = ['Visual Memory', 'Working Memory', 'Short-term Memory',
                     'Focus Attention', 'Updating', 'Hand-Eye Coordination',
                     'Spatial Perception', 'Reaction Time', 'Processing Speed',
                     'Planning and Reasoning']

    # Use more descriptive column names for extracting data from the DataFrame
    column_mapping = {
        'Visual Memory': 'Visual Memory Test',
        'Working Memory': 'Visual Working Memory Span',
        'Short-term Memory': 'Digit Span Test',
        'Focus Attention': 'Selective Attention Test',
        'Updating': 'Inhibition of Return Test',
        'Hand-Eye Coordination': 'Eye-Hand Coordination Test',
        'Spatial Perception': 'Maze Test',
        'Reaction Time': 'Psychomotor Vigilance Test',
        'Processing Speed': 'Digit Span Test',
        'Planning and Reasoning': 'Maze Test',
    }

    ability_means = {ability: df[column_mapping.get(ability, ability)].mean() for ability in ability_names}

    # Format the mean values to two decimal places
    table_data = [[ability, f"{ability_means[ability]:.2f}"] for ability in ability_names]

    # Set column widths: first column wider than the second
    col_widths = [0.69, 0.31]  # 70% for the first column, 30% for the second

    table = ax1.table(cellText=table_data,
                      colLabels=["Cognitive Ability", "Final Score"],
                      cellLoc='center',
                      loc='center',
                      colWidths=col_widths)

    # Modify the font properties of column labels
    for (row, col), cell in table.get_celld().items():
        if row == 0:
            cell.set_text_props(weight='bold', fontsize=12)

    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1, 1.5)

    # Figure 2: Heptagon Plot with 10 parameters
    ax2 = fig.add_subplot(2, 2, 2, polar=True)

    # Use the ability means for the heptagon
    labels = [row[0] for row in table_data]
    values = [float(row[1]) for row in table_data]

    # Add the first value to the end of the lists to close the heptagon
    values = np.append(values, values[0])
    angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
    angles += angles[:1]  # Add the first angle to the end to close the heptagon

    ax2.fill(angles, values, color='blue', alpha=0.25)
    ax2.plot(angles, values, color='blue', linewidth=1)
    ax2.set_yticklabels([])
    ax2.set_xticks(angles[:-1])
    ax2.set_xticklabels(labels, fontsize=8)

    # Figure 3: Vertical bar chart (Page 2)
    ax3 = fig.add_subplot(2, 1, 2)
    y_pos = np.arange(len(labels))
    values_percent = values[:-1]  # Already formatted to two decimal places

    # Ensure y_pos and values_percent have the same length
    min_len = min(len(y_pos), len(values_percent))
    y_pos = y_pos[:min_len]
    values_percent = values_percent[:min_len]

    ax3.bar(y_pos, values_percent, align='center')
    ax3.set_xticks(y_pos)
    ax3.set_xticklabels(['\n'.join(label.split()) for label in labels], fontsize=5, rotation=0, ha='center')

    for i, v in enumerate(values_percent):
        ax3.text(i, v + 1, f"{v:.1f}", color='blue', ha='center', fontsize=8)

    ax3.set_ylim(0, max(100, max(values_percent) + 10))  # Set y-axis limit from 0 to max percentage
    ax3.set_yticks(range(0, int(max(100, max(values_percent) + 10)) + 1, 20))  # Set y-axis ticks
    ax3.set_yticklabels([str(i) for i in range(0, int(max(100, max(values_percent) + 10)) + 1, 20)])  # Remove % symbol from y-axis labels
    ax3.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines

    # Add the second logo to the bottom-right corner
    logo2 = Image.open('/content/Logo2.png')
    logo2 = logo2.resize((70, 70))  # Resize the logo to a smaller size
    fig.figimage(logo2, fig.bbox.xmax - 50 - logo2.size[0], fig.bbox.ymin + 50)  # Position the logo at the bottom-right corner

    # Save the first page
    pdf.savefig(fig)
    plt.close(fig)

    # ----------------------------------------------- Page 3 -----------------------------------------------
    fig = plt.figure(figsize=(8.27, 11.69))  # A4 size in inches

    # Add logo and title to the top-left corner
    fig.figimage(logo1, 50, fig.bbox.ymax - 50 - logo1.size[1])  # Position the logo at the top-left corner

    # Add personal information to the center-top of the page
    fig.text(0.5, 0.95, "Name:               Age:    Date of Evaluation:", fontsize=10, ha='center')
    fig.text(0.5, 0.93, f"{name}    {age}    {date}", fontsize=10, ha='center')

    # Add the title "Assessment Results" close to the figures
    fig.text(0.5, 0.85, "Assessment Results", fontsize=12, ha='center', weight='bold')

    # Add a 3-column 7-row table with size matching the bar chart
    ax4 = fig.add_subplot(2, 1, 1)
    ax4.axis('tight')
    ax4.axis('off')

    # Sample data for the table with formatted mean values
    table_data_page2 = [['Assessment Name', 'Score', 'Description'],
                        ['Psychomotor Vigilance Test', f"{ability_means['Reaction Time']:.2f}", 'Description 1'],
                        ['Eye-Hand Coordination Test', f"{ability_means['Hand-Eye Coordination']:.2f}", 'Description 2'],
                        ['Eye-Hand Coordination MUD', f"{ability_means['Hand-Eye Coordination']:.2f}", 'Description 3'],
                        ['Maze Test', f"{ability_means['Planning and Reasoning']:.2f}", 'Description 4'],
                        ['Digit Span Test', f"{ability_means['Short-term Memory']:.2f}", 'Description 5'],
                        ['Visual Memory Test', f"{ability_means['Visual Memory']:.2f}", 'Description 6']]

    # Set column widths: 22% for first column, 11% for second, and the rest (67%) for the third
    col_widths = [0.22, 0.11, 0.67]

    table_page2 = ax4.table(cellText=table_data_page2,
                            cellLoc='center',
                            loc='center',
                            colWidths=col_widths)

    # Modify the font properties of column labels
    for (row, col), cell in table_page2.get_celld().items():
        if row == 0:
            cell.set_text_props(weight='bold', fontsize=12)

    table_page2.auto_set_font_size(False)
    table_page2.set_fontsize(6)
    table_page2.scale(1, 1.5)

    # Figure 4: Vertical bar chart (Page 3)
    ax5 = fig.add_subplot(2, 1, 2)
    labels_page2 = [row[0] for row in table_data_page2[1:]]  # Exclude header row
    values_page2 = [float(row[1]) for row in table_data_page2[1:]]  # Use the formatted mean values
    y_pos_page2 = np.arange(len(labels_page2))

    ax5.bar(y_pos_page2, values_page2, align='center')
    ax5.set_xticks(y_pos_page2)
    ax5.set_xticklabels(['\n'.join(label.split()) for label in labels_page2], fontsize=5, rotation=0, ha='center')

    for i, v in enumerate(values_page2):
        ax5.text(i, v + 1, f"{v:.1f}", color='blue', ha='center', fontsize=8)

    ax5.set_ylim(0, max(100, max(values_page2) + 10))  # Set y-axis limit from 0 to max percentage
    ax5.set_yticks(range(0, int(max(100, max(values_page2) + 10)) + 1, 20))  # Set y-axis ticks
    ax5.set_yticklabels([str(i) for i in range(0, int(max(100, max(values_page2) + 10)) + 1, 20)])  # Remove % symbol from y-axis labels
    ax5.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines

    # Add the second logo to the bottom-right corner
    fig.figimage(logo2, fig.bbox.xmax - 50 - logo2.size[0], fig.bbox.ymin + 50)  # Position the logo at the bottom-right corner

    # Save the second page
    pdf.savefig(fig)
    plt.close(fig)

    # Close the PDF file
    pdf.close()

    # Merge front cover, report, and back cover
    front_pdf = PdfReader(front_cover_path)
    report_pdf = PdfReader(output_pdf)
    back_pdf = PdfReader(back_cover_path)

    output = PdfWriter()

    # Add front cover
    output.add_page(front_pdf.pages[0])

    # Add report pages
    for page in report_pdf.pages:
        output.add_page(page)

    # Add back cover
    output.add_page(back_pdf.pages[0])

    # Save the merged PDF
    with open(output_pdf, 'wb') as f:
        output.write(f)

    # Download the merged PDF
    files.download(output_pdf)

# Example usage with a sample DataFrame
data = {
    'Visual Memory Test': np.random.rand(100),
    'Visual Working Memory Span': np.random.rand(100),
    'Digit Span Test': np.random.rand(100),
    'Selective Attention Test': np.random.rand(100),
    'Inhibition of Return Test': np.random.rand(100),
    'Eye-Hand Coordination Test': np.random.rand(100),
    'Maze Test': np.random.rand(100),
    'Psychomotor Vigilance Test': np.random.rand(100)
}
df = pd.DataFrame(data)
plot_maker(df)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define data
table_data = [['Visual Memory', 'Value 1'], ['Working Memory', 'Value 2'], ['Short-term Memory', 'Value 3'],
              ['Focus Attention', 'Value 4'], ['Updating', 'Value 5'], ['Hand-Eye Coordination', 'Value 6'],
              ['Spatial Perception', 'Value 7'], ['Reaction Time', 'Value 8'], ['Processing Speed', 'Value 9'],
              ['Planning and Reasoning', 'Value 10']]

# Use the first 10 elements from table_data for the plot
labels = [row[0] for row in table_data]
values = np.random.randint(0, 100, size=len(labels))  # Generate random data for demonstration

# Add the first value to the end of the lists to close the heptagon
values = np.append(values, values[0])
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]

fig, ax2 = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

# Plotting the heptagon
ax2.fill(angles, values, color='blue', alpha=0.25)
ax2.plot(angles, values, color='blue', linewidth=1)

# Setting colors and ranges
colors = ['red', 'orange', 'yellow', 'green']
ranges = [(0, 25), (25, 50), (50, 75), (75, 100)]
for i in range(len(ranges)):
    ax2.fill_between(angles, ranges[i][0], ranges[i][1], color=colors[i], alpha=0.2)

# Draw a 50% line
ax2.plot(angles, [50] * len(angles), color='black', linestyle='--', linewidth=1)

# Setting labels
plt.xticks(angles[:-1], labels, fontsize=8)
ax2.set_yticklabels([])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate data for normal distribution
mean = 50  # Set mean to 50
std_dev = 16
x = np.linspace(0, 100, 1000)  # Values from 0 to 100
y = stats.norm.pdf(x, mean, std_dev)

# Create the figure and axis with increased width
fig, ax = plt.subplots(figsize=(15, 6))

# Plot the bell curve with a gradient color fill
ax.plot(x, y, color='darkblue', linewidth=2)
ax.fill_between(x, y, color='lightblue', alpha=0.5)

# Plot settings
ax.set_title('Normal Distribution', fontsize=14, fontweight='bold')
ax.set_xlabel('Value', fontsize=12)
ax.set_ylabel('Probability Density', fontsize=12)
ax.set_xticks(value_labels)  # Set x-ticks to the value labels
ax.grid(True, linestyle='--', linewidth=0.5)
ax.set_facecolor('white')

# Enhance plot appearance
fig.patch.set_facecolor('white')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.xaxis.label.set_color('gray')
ax.yaxis.label.set_color('gray')
ax.tick_params(axis='x', colors='gray')
ax.tick_params(axis='y', colors='gray')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate data for normal distribution
mean = 50
std_dev = 16
x = np.linspace(0, 100, 1000)
y = stats.norm.pdf(x, mean, std_dev)

# Create the figure and axis with increased width
fig, ax = plt.subplots(figsize=(15, 6))

# Plot the bell curve
ax.plot(x, y, color='darkblue', linewidth=2)

# Fill different regions with specified colors
ax.fill_between(x, y, where=(x < 25), color='red', alpha=0.3)
ax.fill_between(x, y, where=(x >= 25) & (x < 50), color='orange', alpha=0.3)
ax.fill_between(x, y, where=(x >= 50) & (x < 75), color='yellow', alpha=0.3)
ax.fill_between(x, y, where=(x >= 75), color='green', alpha=0.3)

# Add vertical lines at 25, 50, and 75
ax.axvline(x=25, color='gray', linestyle='--', linewidth=1)
ax.axvline(x=50, color='gray', linestyle='--', linewidth=1)
ax.axvline(x=75, color='gray', linestyle='--', linewidth=1)

# Plot settings
ax.set_title('Normal Distribution', fontsize=14, fontweight='bold')
ax.set_xlabel('Value', fontsize=12)
ax.set_ylabel('Probability Density', fontsize=12)
ax.grid(True, linestyle='--', linewidth=0.5)
ax.set_facecolor('white')

# Enhance plot appearance
fig.patch.set_facecolor('white')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.xaxis.label.set_color('gray')
ax.yaxis.label.set_color('gray')
ax.tick_params(axis='x', colors='gray')
ax.tick_params(axis='y', colors='gray')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Generate data for normal distribution
mean = 50
std_dev = 16
x = np.linspace(0, 100, 1000)
y = stats.norm.pdf(x, mean, std_dev)

# Create the figure and axis
fig, ax = plt.subplots(figsize=(15, 6))

# Create a custom colormap from red to green
custom_cmap = plt.cm.get_cmap('RdYlGn')

# Plot the bell curve with gradient color
scatter = ax.scatter(x, y, c=x, cmap=custom_cmap, s=1)

# Fill the area under the curve
ax.fill_between(x, y, color='none', alpha=0.3)

# Plot settings
ax.set_title('Normal Distribution', fontsize=14, fontweight='bold')
ax.set_xlabel('Value', fontsize=12)
ax.set_ylabel('Probability Density', fontsize=12)
ax.grid(True, linestyle='--', linewidth=0.5)
ax.set_facecolor('white')

# Enhance plot appearance
fig.patch.set_facecolor('white')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.xaxis.label.set_color('gray')
ax.yaxis.label.set_color('gray')
ax.tick_params(axis='x', colors='gray')
ax.tick_params(axis='y', colors='gray')

# Add a colorbar
plt.colorbar(scatter, label='Value')

plt.show()
# Out:
# <ipython-input-43-2e6e48a895cd>:15: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   custom_cmap = plt.cm.get_cmap('RdYlGn')

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from matplotlib.colors import LinearSegmentedColormap

# Set parameters for the normal distribution
mean = 50
std_dev = 16
x = np.linspace(0, 100, 1000)
y = stats.norm.pdf(x, mean, std_dev)

# Create figure and axis
fig, ax = plt.subplots(figsize=(15, 6))

# Create a custom colormap from red to green
colors = ['red', 'yellow', 'green']
n_bins = 100
cmap = LinearSegmentedColormap.from_list('custom', colors, N=n_bins)

# Fill the area under the curve with gradient color
for i in range(len(x)-1):
    ax.fill_between(x[i:i+2], y[i:i+2], color=cmap(i/len(x)), alpha=0.6)

# Plot the main curve
ax.plot(x, y, color='black', linewidth=2)

# Set plot settings
ax.set_title('Normal Distribution', fontsize=14, fontweight='bold')
ax.set_xlabel('Value', fontsize=12)
ax.set_ylabel('Probability Density', fontsize=12)
ax.grid(True, linestyle='--', linewidth=0.5)
ax.set_facecolor('white')

# Enhance plot appearance
fig.patch.set_facecolor('white')
for spine in ax.spines.values():
    spine.set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.xaxis.label.set_color('gray')
ax.yaxis.label.set_color('gray')
ax.tick_params(axis='x', colors='gray')
ax.tick_params(axis='y', colors='gray')

# Add a colorbar
sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=0, vmax=100))
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax)
cbar.set_label('Value')

plt.show()

# %%
pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from PIL import Image
from matplotlib.backends.backend_pdf import PdfPages
from PyPDF2 import PdfReader, PdfWriter
from google.colab import files
from matplotlib.font_manager import FontProperties

def plot_maker(df, output_pdf='report.pdf', name="Armin Abdollahi", age=25, date="2025-01-31"):
    front_cover_path = '/content/Front_Cover.pdf'
    back_cover_path = '/content/Back_Cover.pdf'

    # Create a PDF object
    pdf = PdfPages(output_pdf)

    # Create a figure with subplots of size A4
    fig = plt.figure(figsize=(8.27, 11.69))  # A4 size in inches

    # ----------------------------------------------- Page 2 -----------------------------------------------
    # Add logo and title to the top-left corner
    logo1 = Image.open('/content/Logo1.png')
    logo1 = logo1.resize((140, 27))  # Resize the logo to a smaller size
    fig.figimage(logo1, 50, fig.bbox.ymax - 50 - logo1.size[1])  # Position the logo at the top-left corner

    # Add personal information to the center-top of the page
    fig.text(0.5, 0.95, "Name:               Age:    Date of Evaluation:", fontsize=10, ha='center')
    fig.text(0.5, 0.93, f"{name}    {age}    {date}", fontsize=10, ha='center')

    # Add the title "CogniFit Profile" close to the figures
    fig.text(0.5, 0.85, "Cognitive Profile", fontsize=12, ha='center', weight='bold')

    # Create a table
    ax1 = fig.add_subplot(2, 2, 1)
    ax1.axis('tight')
    ax1.axis('off')

    # Sample data for the table
    table_data = [['Visual Memory', 'Value 1'], ['Working Memory', 'Value 2'], ['Short-term Memory', 'Value 3'],
                  ['Focus Attention', 'Value 4'], ['Updating', 'Value 5'], ['Hand-Eye Coordination', 'Value 6'],
                  ['Spatial Perception', 'Value 7'], ['Reaction Time', 'Value 8'], ['Processing Speed', 'Value 9'],
                  ['Planning and Reasoning', 'Value 10']]

    # Set column widths: first column wider than the second
    col_widths = [0.69, 0.31]  # 70% for the first column, 30% for the second

    table = ax1.table(cellText=table_data,
                      colLabels=["Cognitive Ability", "Final Score"],
                      cellLoc='center',
                      loc='center',
                      colWidths=col_widths)

    # Modify the font properties of column labels
    for (row, col), cell in table.get_celld().items():
        if row == 0:
            cell.set_text_props(weight='bold', fontsize=12)

    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1, 1.5)

    # Figure 2: Heptagon Plot with 10 parameters
    ax2 = fig.add_subplot(2, 2, 2, polar=True)

    # Use the first 10 elements from table_data for the heptagon
    labels = [row[0] for row in table_data]
    values = np.random.randint(0, 100, size=len(labels))  # Generate random data for demonstration

    # Add the first value to the end of the lists to close the heptagon
    values = np.append(values, values[0])
    angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
    angles += angles[:1]

    ax2.fill(angles, values, color='blue', alpha=0.25)
    ax2.plot(angles, values, color='blue', linewidth=1)

    # Setting colors and ranges
    colors = ['red', 'orange', 'yellow', 'green']
    ranges = [(0, 25), (25, 50), (50, 75), (75, 100)]
    for i in range(len(ranges)):
        ax2.fill_between(angles, ranges[i][0], ranges[i][1], color=colors[i], alpha=0.2)

    # Draw a 50% line
    ax2.plot(angles, [50] * len(angles), color='black', linestyle='--', linewidth=1)

    ax2.set_yticklabels([])
    ax2.set_xticks(angles[:-1])
    ax2.set_xticklabels(labels, fontsize=8)

    # Figure 3: Vertical bar chart (Page 2)
    ax3 = fig.add_subplot(2, 1, 2)
    y_pos = np.arange(len(labels))
    values_percent = values[:-1] * 100  # Convert to percentage
    ax3.bar(y_pos, values_percent, align='center')
    ax3.set_xticks(y_pos)
    ax3.set_xticklabels(['\n'.join(label.split()) for label in labels], fontsize=5, rotation=0, ha='center')
    for i, v in enumerate(values_percent):
        ax3.text(i, v + 1, f"{v:.1f}", color='blue', ha='center', fontsize=8)
    ax3.set_ylim(0, 100)  # Set y-axis limit from 0 to 100
    ax3.set_yticks(range(0, 101, 20))  # Set y-axis ticks from 0 to 100 with step of 20
    ax3.set_yticklabels([str(i) for i in range(0, 101, 20)])  # Remove % symbol from y-axis labels
    ax3.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines

    # Add the second logo to the bottom-right corner
    logo2 = Image.open('/content/Logo2.png')
    logo2 = logo2.resize((70, 70))  # Resize the logo to a smaller size
    fig.figimage(logo2, fig.bbox.xmax - 50 - logo2.size[0], fig.bbox.ymin + 50)  # Position the logo at the bottom-right corner

    # Save the first page
    pdf.savefig(fig)
    plt.close(fig)

    # ----------------------------------------------- Page 3 -----------------------------------------------
    fig = plt.figure(figsize=(8.27, 11.69))  # A4 size in inches

    # Add logo and title to the top-left corner
    fig.figimage(logo1, 50, fig.bbox.ymax - 50 - logo1.size[1])  # Position the logo at the top-left corner

    # Add personal information to the center-top of the page
    fig.text(0.5, 0.95, "Name:               Age:    Date of Evaluation:", fontsize=10, ha='center')
    fig.text(0.5, 0.93, f"{name}    {age}    {date}", fontsize=10, ha='center')

    # Add the title "Assessment Results" close to the figures
    fig.text(0.5, 0.85, "Assessment Results", fontsize=12, ha='center', weight='bold')

    # Add a 3-column 7-row table with size matching the bar chart
    ax4 = fig.add_subplot(2, 1, 1)
    ax4.axis('tight')
    ax4.axis('off')

    # Sample data for the table
    table_data_page2 = [['Assessment Name', 'Score', 'Description'],
                        ['Psychomotor Vigilance Test', 'Value 1.2', 'Value 1.3'],
                        ['Eye-Hand Coordination Test', 'Value 2.2', 'Value 2.3'],
                        ['Eye-Hand Coordination MUD', 'Value 3.2', 'Value 3.3'],
                        ['Maze Test', 'Value 4.2', 'Value 4.3'],
                        ['Digit Span Test', 'Value 5.2', 'Value 5.3'],
                        ['Visual Memory Test', 'Value 6.2', 'Value 6.3']]

    # Set column widths: 22% for first column, 11% for second, and the rest (67%) for the third
    col_widths = [0.22, 0.11, 0.67]

    table_page2 = ax4.table(cellText=table_data_page2,
                            cellLoc='center',
                            loc='center',
                            colWidths=col_widths)

    # Modify the font properties of column labels
    for (row, col), cell in table_page2.get_celld().items():
        if row == 0:
            cell.set_text_props(weight='bold', fontsize=12)

    table_page2.auto_set_font_size(False)
    table_page2.set_fontsize(6)
    table_page2.scale(1, 1.5)  # Scale to match bar chart size

    # Figure 4: Vertical bar chart (Page 3)
    ax5 = fig.add_subplot(2, 1, 2)
    labels_page2 = [row[0] for row in table_data_page2[1:]]  # Exclude header row
    values_page2 = np.random.rand(len(labels_page2)) * 100  # Generate random data as percentage
    y_pos_page2 = np.arange(len(labels_page2))
    ax5.bar(y_pos_page2, values_page2, align='center')
    ax5.set_xticks(y_pos_page2)
    ax5.set_xticklabels(['\n'.join(label.split()) for label in labels_page2], fontsize=5, rotation=0, ha='center')
    for i, v in enumerate(values_page2):
        ax5.text(i, v + 1, f"{v:.1f}", color='blue', ha='center', fontsize=8)
    ax5.set_ylim(0, 100)  # Set y-axis limit from 0 to 100
    ax5.set_yticks(range(0, 101, 20))  # Set y-axis ticks from 0 to 100 with step of 20
    ax5.set_yticklabels([str(i) for i in range(0, 101, 20)])  # Remove % symbol from y-axis labels
    ax5.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines

    # Add the second logo to the bottom-right corner
    fig.figimage(logo2, fig.bbox.xmax - 50 - logo2.size[0], fig.bbox.ymin + 50)  # Position the logo at the bottom-right corner

    # Save the second page
    pdf.savefig(fig)
    plt.close(fig)

    # Close the PDF file
    pdf.close()

    # Merge front cover, report, and back cover
    front_pdf = PdfReader(front_cover_path)
    report_pdf = PdfReader(output_pdf)
    back_pdf = PdfReader(back_cover_path)

    output = PdfWriter()

    # Add front cover
    output.add_page(front_pdf.pages[0])

    # Add report pages
    for page in report_pdf.pages:
        output.add_page(page)

    # Add back cover
    output.add_page(back_pdf.pages[0])

    # Save the merged PDF
    with open(output_pdf, 'wb') as f:
        output.write(f)

    # Download the merged PDF
    files.download(output_pdf)

# Example usage with a sample dataframe
data = {
    'Visual Memory': np.random.rand(100),
    'Working Memory': np.random.rand(100),
    'Short-term Memory': np.random.rand(100),
    'Focus Attention': np.random.rand(100),
    'Updating': np.random.rand(100),
    'Hand-Eye Coordination': np.random.rand(100),
    'Spatial Perception': np.random.rand(100),
    'Reaction Time': np.random.rand(100),
    'Processing Speed': np.random.rand(100),
    'Planning and Reasoning': np.random.rand(100),
    'Psychomotor Vigilance Test': np.random.rand(100),
    'Eye-Hand Coordination Test': np.random.rand(100),
    'Eye-Hand Coordination MUD': np.random.rand(100),
    'Maze Test': np.random.rand(100),
    'Digit Span Test': np.random.rand(100),
    'Visual Memory Test': np.random.rand(100),
    'Visual Working Memory Span': np.random.rand(100)
}
df = pd.DataFrame(data)
plot_maker(df)
